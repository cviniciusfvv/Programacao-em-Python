# %% [markdown]
# # Aula 7: Introdução à Linguagem de Programação Python
# Bem vindo ao Google Colaboratory! Nós iremos utilizar essa plataforma para fazer nossas atividades com o Python. Vamos fazer alguns testes?

# %% [markdown]
# # Listas
# Lista é uma coleção de valores indexada, em que cada valor é identificado por um índice. O primeiro item na lista está no índice 0, o segundo no índice 1 e assim por diante.
#
# Para criar uma lista com elementos deve-se usar colchetes e adicionar os itens entre eles separados por vírgula

# %%
programadores = ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']
print(type(programadores)) # type ‘list’
print(len(programadores)) # 5
print(programadores[4]) # Luana
# Out:
# <class 'list'>
# 5
# Luana

# %% [markdown]
# Outra característica das listas no Python é que elas são mutáveis, podendo ser alteradas depois de terem sido criadas. Em outras palavras, podemos adicionar, remover e até mesmo alterar os itens de uma lista.

# %%
programadores = ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']
print(programadores) # ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']

programadores[1] = 'Carolina'
print(programadores) # ['Victor', 'Carolina', 'Samuel', 'Caio', 'Luana']
# Out:
# ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']
# ['Victor', 'Carolina', 'Samuel', 'Caio', 'Luana']

# %% [markdown]
# Além de alterar elementos em listas, também é possível adicionar itens nelas, pois já vêm com uma coleção de métodos predefinidos que podem ser usados para manipular os objetos que ela contém.

# %%
programadores = ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']
print(programadores) # ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana

programadores.append('Renato')
programadores.append('João')

print(programadores) # ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana', 'Renato']
# Out:
# ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']
# ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana', 'Renato', 'João']

# %% [markdown]
# Há outra forma de adicionarmos itens na lista, que é através do método insert().

# %%
programadores = ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']
programadores.insert(1, 'Raul')

print(programadores) # ['Victor', 'Rafael', 'Juliana', 'Samuel', 'Caio', 'Luana']
# Out:
# ['Victor', 'Raul', 'Juliana', 'Samuel', 'Caio', 'Luana']

# %% [markdown]
# Assim como podemos adicionar itens em nossa lista, também podemos retirá-los.

# %%
programadores = ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']
print(programadores) # ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']

programadores.remove('Luana')
print(programadores) # ['Juliana', 'Samuel', 'Caio', 'Luana']
# Out:
# ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']
# ['Victor', 'Juliana', 'Samuel', 'Caio']

# %% [markdown]
# Também é possível remover um item pelo seu índice

# %%
programadores = ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']
print(programadores) # ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']

programadores.pop(3)
print(programadores) # ['Juliana', 'Samuel', 'Caio', 'Luana']
# Out:
# ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana']
# ['Victor', 'Juliana', 'Samuel', 'Luana']

# %% [markdown]
# ---

# %% [markdown]
# # Tuplas
# Tupla é uma estrutura de dados semelhante a lista. Porém, ela tem a característica de ser imutável, ou seja, após uma tupla ser criada, ela não pode ser alterada.

# %%
times_sp = ('São Paulo', 'Timão', 'Palmeiras', 'Peixão')

print(type(times_sp)) # class=’tuple’
print(times_sp) # ('Botafogo', 'Flamengo', 'Fluminense', 'Vasco')
# Out:
# <class 'tuple'>
# ('São Paulo', 'Timão', 'Palmeiras', 'Peixão')

# %% [markdown]
# Assim como é feito nas listas, podemos acessar um determinado valor na tupla pelo seu índice

# %%
times_sp = ('São Paulo', 'Timão', 'Palmeiras', 'Peixão')

print(times_sp[3]) # Fluminense
# Out:
# Peixão

# %% [markdown]
# # Dicionários

# %% [markdown]
# Os dicionários representam coleções de dados que contém na sua estrutura um conjunto de pares chave/valor, nos quais cada chave individual tem um valor associado. Esse objeto representa a ideia de um mapa, que entendemos como uma coleção associativa desordenada. A associação nos dicionários é feita por meio de uma chave que faz referência a um valor.

# %%
dados_cliente = {
    'Nome': 'Renan',
    'Endereco': 'Rua Cruzeiro do Sul',
    'Telefone': '982503645'
}

print(dados_cliente) # Renan

# %% [markdown]
# Para adicionar elementos num dicionário basta associar uma nova chave ao objeto e dar um valor a ser associado a ela. No Código vamos colocar a informação Idade em dados_cliente.

# %%
dados_cliente = {
    'Nome': 'Renan',
    'Endereco': 'Rua Cruzeiro do Sul',
    'Telefone': '982503645'
}

print(dados_cliente) # {'Nome': 'Renan', 'Endereco': 'Rua Cruzeiro do Sul', 'Telefone': '982503645'}

dados_cliente['Idade'] = 40
dados_cliente['Apelido'] = "Zé ruela"

print(dados_cliente) # {'Nome': 'Renan', 'Endereco': 'Rua Cruzeiro do Sul','Telefone': '982503645', 'Idade': 40}
# Out:
# {'Nome': 'Renan', 'Endereco': 'Rua Cruzeiro do Sul', 'Telefone': '982503645'}
# {'Nome': 'Renan', 'Endereco': 'Rua Cruzeiro do Sul', 'Telefone': '982503645', 'Idade': 40, 'Apelido': 'Zé ruela'}

# %% [markdown]
# Para remover um item do dicionário, podemos usar o método pop()

# %%
dados_cliente = {
    'Nome': 'Renan',
    'Endereco': 'Rua Cruzeiro do Sul',
    'Telefone': '982503645'
}

print(dados_cliente) # {'Nome': 'Renan', 'Endereco': 'Rua Cruzeiro do Sul','Telefone': '982503645'}

dados_cliente.pop('Telefone')

print(dados_cliente) # {'Nome': 'Renan', 'Endereco': 'Rua Cruzeiro do Sul'}
# Out:
# {'Nome': 'Renan', 'Endereco': 'Rua Cruzeiro do Sul', 'Telefone': '982503645'}
# {'Nome': 'Renan', 'Endereco': 'Rua Cruzeiro do Sul'}

# %% [markdown]
# # Exercícios

# %% [markdown]
# 01 - Crie uma **lista** com 6 nomes de personagens de desenho. Altere o nome do terceiro personagem. Inserir mais um nome no final da lista.

# %%
programadores = ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana', 'Carlos']
print(programadores)

programadores[2] = 'Carolina'
print(programadores)

programadores.append('Renato')
print(programadores)
# Out:
# ['Victor', 'Juliana', 'Samuel', 'Caio', 'Luana', 'Carlos']
# ['Victor', 'Juliana', 'Carolina', 'Caio', 'Luana', 'Carlos']
# ['Victor', 'Juliana', 'Carolina', 'Caio', 'Luana', 'Carlos', 'Renato']

# %% [markdown]
# 02 - Crie uma **tupla** com o nome de todos os planetas do sistema solar e ao final imprimir a tupla.

# %%
planetas_sis_solar = ('Mercurio', 'Venus', 'Terra', 'Marte', 'Jupiter', 'Saturno', 'Urano', 'Netuno')
print(planetas_sis_solar)
# Out:
# ('Mercurio', 'Venus', 'Terra', 'Marte', 'Jupiter', 'Saturno', 'Urano', 'Netuno')

# %% [markdown]
# 03 - Crie um **dicionário** com os dados dos alunos ( RA, Nome, Endereço, Email, Fone, Curso). Listar os valores do dicionário.
