# %%
pip install pandas
pip install lxml
pip install plotly
# Out:
#   File "C:\Users\aluno\AppData\Local\Temp\ipykernel_7468\3663876541.py", line 1
#     pip install lxml
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
url = 'https://pt.wikipedia.org/wiki/Big_Brother_Brasil_21'
html = pd.read_html(url, match= ' dos votos')
html
# Out:
# [    Pos.       Participante    Meio de indicação      % dos votos Eliminado em
#  0      1    Juliette Freire            Finalista        90,15%[2]            —
#  1      2   Camilla de Lucas            Finalista         5,23%[2]            —
#  2      3               Fiuk            Finalista         4,62%[2]            —
#  3      4  Gilberto Nogueira   Prova do Finalista       50,87%[63]    Semana 14
#  4      5              Pocah     Líder (Juliette)      73,16%[270]    Semana 14
#  5      6      Arthur Picoli       Casa (3 votos)       61,34%[61]    Semana 13
#  6      7          Viih Tube       Casa (3 votos)      96,69%[271]    Semana 13
#  7      8  João Luiz Pedrosa       Casa (2 votos)      58,86%[272]    Semana 13
#  8      9        Caio Afiune       Casa (3 votos)      70,22%[273]    Semana 12
#  9     10         Thaís Braz         Líder (Caio)      82,29%[274]    Semana 11
#  10    11  Rodolffo Matthaus       Casa (4 votos)       50,48%[60]    Semana 10
# ...

# %%
listabbb = html[0]
listabbb
# Out:
#     Pos.       Participante    Meio de indicação      % dos votos Eliminado em
# 0      1    Juliette Freire            Finalista        90,15%[2]            —
# 1      2   Camilla de Lucas            Finalista         5,23%[2]            —
# 2      3               Fiuk            Finalista         4,62%[2]            —
# 3      4  Gilberto Nogueira   Prova do Finalista       50,87%[63]    Semana 14
# 4      5              Pocah     Líder (Juliette)      73,16%[270]    Semana 14
# 5      6      Arthur Picoli       Casa (3 votos)       61,34%[61]    Semana 13
# 6      7          Viih Tube       Casa (3 votos)      96,69%[271]    Semana 13
# 7      8  João Luiz Pedrosa       Casa (2 votos)      58,86%[272]    Semana 13
# 8      9        Caio Afiune       Casa (3 votos)      70,22%[273]    Semana 12
# 9     10         Thaís Braz         Líder (Caio)      82,29%[274]    Semana 11
# 10    11  Rodolffo Matthaus       Casa (4 votos)       50,48%[60]    Semana 10
# ...

# %%
for i in range (1, 18):
    print(pd.read_html(url))
# Out:
# [                                   Big Brother Brasil  \
#                                        21.ª temporada
# 0                                                 NaN
# 1                                Transmissão original
# 2                                    Apresentador(es)
# 3                                            Emissora
# 4                                         Música-tema
# 5                                    N.° de episódios
# 6                                            Vencedor
# 7                                     Juliette Freire
# 8                                        Vice-campeão
# 9                                    Camilla de Lucas
# 10                                         Cronologia
# 11  ← Anterior  Próxima → 20.ª temporada 22.ª temp...
# 12                                         ← Anterior
# 13                                     20.ª temporada
#
#
#                                      21.ª temporada.1
# ...

# %%
add_data = []
for i in range (1,15):
    add_data.append(pd.read_html(url)[i])
add_data
# Out:
# [                0               1
#  0      ← Anterior       Próxima →
#  1  20.ª temporada  22.ª temporada,
#        Grupo Participante Porcentagem  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
#  0    Pipoca       Lumena      18,42%         NaN         NaN         NaN
#  1    Pipoca     Juliette      13,96%         NaN         NaN         NaN
#  2    Pipoca       Arthur      13,42%         NaN         NaN         NaN
#  3       NaN          NaN         NaN         NaN         NaN         NaN
#  4  Camarote         Fiuk      15,57%         NaN         NaN         NaN
#  5  Camarote    Viih Tube      12,61%         NaN         NaN         NaN
#  6  Camarote      Projota      11,98%         NaN         NaN         NaN
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
#  0         NaN         NaN         NaN         NaN          NaN          NaN
#  1         NaN         NaN         NaN         NaN          NaN          NaN
# ...

# %%
df = pd.concat(add_data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 248 entries, 0 to 8
# Data columns (total 92 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   0                                           2 non-null      object
#  1   1                                           4 non-null      object
#  2   Grupo                                       6 non-null      object
#  3   Participante                                46 non-null     object
#  4   Porcentagem                                 6 non-null      object
#  5   Unnamed: 3                                  0 non-null      float64
#  6   Unnamed: 4                                  0 non-null      float64
#  7   Unnamed: 5                                  0 non-null      float64
#  8   Unnamed: 6                                  0 non-null      float64
#  9   Unnamed: 7                                  0 non-null      float64
# ...

# %%
import plotly.express as go

# %%
bbb21 = html[0]
lista =[bbb21]
dados = pd.concat(lista)

go.funnel(dados, x='Participante', y='% dos votos')
