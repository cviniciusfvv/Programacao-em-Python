# %% [markdown]
# ## Exercicio Final - Game e antiguidade

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

while True:
    cd = int(input("Qual opção você quer: 1 - Yu Gi Oh, 2 - Magic, 3 - Pokemon TCG, 0 - sair: ")) #escolha seu card game
    if cd == 0:
        print("Saindo do programa. Até mais!")
        break  # Encerra o loop
    if cd == 1: #Yu Gi Oh
        while True:
            yugioh = int(input("O que você procura sobre Yu Gi Oh: 1 - Cartas, 2 - Booster, 3 - Cartas avulsas, 4 - decks 0 - sair:  "))
            if yugioh == 0:
                print("Saindo do programa. Até mais!")
                break  # Encerra o loop interno
            if yugioh == 1: # cartas
                driver = webdriver.Chrome()
                driver.get('https://www.ligayugioh.com.br/?view=cards/edicoes')
                result = driver.find_element(By.XPATH, '//*[@id="tab-edc"]/tbody \n').text
                print(result)
            if yugioh == 2: # Booster
                driver = webdriver.Chrome()
                driver.get('https://www.ligayugioh.com.br/?view=cards/edicoes')
                result = driver.find_element(By.XPATH, '//*[@id="tab-edc"]/tbody \n').text
                print(result)
            if yugioh == 3: # cartas avulsas
                driver = webdriver.Chrome()
                driver.get('https://www.ligayugioh.com.br/?view=cards/edicoes')
                result = driver.find_element(By.XPATH, '//*[@id="tab-edc"]/tbody \n').text
                print(result)
            if yugioh == 4: # decks
                driver = webdriver.Chrome()
                driver.get('https://www.ligayugioh.com.br/?view=dks/decks')
                result = driver.find_element(By.XPATH, '//*[@id="card-estoque"]/div[3] \n').text
                print(result)
            else:
                print("Opção não existe")
    if cd == 2: #Magic
        while True:
            magic = int(input("O que você procura sobre Magic: 1 - Cartas, 2 - Booster, 3 - Cartas avulsas, 4 - decks 0 - sair:  "))
            if magic == 0:
                print("Saindo do programa. Até mais!")
                break  # Encerra o loop interno
            if magic == 1: # packs
                driver = webdriver.Chrome()
                driver.get('https://www.ligamagic.com.br/?view=cards%2Fsearch&card=booster+pack&tipo=1')
                result = driver.find_element(By.XPATH, '//*[@id="mtg-cards"] \n').text
                print(result)
            if magic == 2: # Booster
                driver = webdriver.Chrome()
                driver.get('https://www.ligamagic.com.br/?view=cards%2Fsearch&card=booster+box&tipo=1')
                result = driver.find_element(By.XPATH, '//*[@id="mtg-cards"]/div[1] \n').text
                print(result)
            if magic == 3: # cartas avulsas
                driver = webdriver.Chrome()
                driver.get('https://www.ligamagic.com.br/?view=leilao/listar')
                result = driver.find_element(By.XPATH, '/html/body/main/div[4]/div \n').text
                print(result)
            if magic == 4: # decks
                driver = webdriver.Chrome()
                driver.get('https://www.ligamagic.com.br/?view=dks/decks')
                result = driver.find_element(By.XPATH, '//*[@id="dks-carrossels"] \n').text
                print(result)
            else:
                print("Opção não existe")
    if cd == 3: #Pokemon tcg
        while True:
            magic = int(input("O que você procura sobre Pokemon TCG: 1 - Cartas, 2 - Booster, 3 - Cartas avulsas, 4 - decks 0 - sair:  "))
            if magic == 0:
                print("Saindo do programa. Até mais!")
                break  # Encerra o loop interno
            if magic == 1: # packs
                driver = webdriver.Chrome()
                driver.get('https://www.ligapokemon.com.br/?view=cards/search&card=categ%3D21+searchprod%3D1')
                result = driver.find_element(By.XPATH, '//*[@id="mtg-cards"] \n').text
                print(result)
            if magic == 2: # Booster
                driver = webdriver.Chrome()
                driver.get('https://www.ligapokemon.com.br/?view=cards/search&card=categ%3D10+searchprod%3D1')
                result = driver.find_element(By.XPATH, '//*[@id="mtg-cards"] \n').text
                print(result)
            if magic == 3: # cartas avulsas
                driver = webdriver.Chrome()
                driver.get('https://www.ligapokemon.com.br/?view=cards/variacao&show=alta')
                result = driver.find_element(By.XPATH, '//*[@id="card-estoque"]/div[3] \n').text
                print(result)
            if magic == 4: # decks
                driver = webdriver.Chrome()
                driver.get('https://www.ligapokemon.com.br/?view=cards/search&card=categ%3D24+searchprod%3D1')
                result = driver.find_element(By.XPATH, '//*[@id="mtg-cards"] \n').text
                print(result)
            else:
                print("Opção não existe")
    else:
        print("Opção não existe")
# Out:
# Leilões encontrados: 42.720 | Busca Avançada
# |
# Ordenar:
#
# Data Finaliza
#                     Lances
#                     Preço
#                     Título
#                     Usuário
#                     Descontos
#
#                     [0-9 / A-Z]
#                     [9-0 / Z-A]
#                  Leilões 1-48 de 42.720
# Páginas:  1 2 3 > >>
# -16.64%
# 1x Astral Dragon - Japonês - Arte estendida
# R$ 25,00
# Finaliza em: 56s
# 1 Trickbind NM PT
# R$ 29,99
# Finaliza em: 1m 28s
# 01 X Hall of the Bandit Lord - FOIL edição
# R$ 500,00
# Finaliza em: 1m 28s
# -13.98%
# GOBLIN BUSHWHASKER - NM
# R$ 12,00
# R$ 15,00
# Finaliza em: 1m 28s
# -13.98%
# GOBLIN BUSHWHASKER - NM
# R$ 12,00
# R$ 15,00
# Finaliza em: 1m 28s
# THINK TWICE - NM
# R$ 2,00
# R$ 5,00
# Finaliza em: 1m 28s
# THINK TWICE - NM
# R$ 2,00
# R$ 5,00
# Finaliza em: 1m 28s
# THINK TWICE - NM
# R$ 2,00
# R$ 5,00
# Finaliza em: 1m 28s
# Startled Awake SP**
# R$ 6,00
# Finaliza em: 1m 28s
# 1x Dragão Pira Funesta / Balefire Dragon - Em Chinês
# R$ 85,00
# Finaliza em: 1m 29s
# 1x Maldição da Presa Vigiada / Curse of Stalked Prey - Em Chinês
# R$ 1,00
# Finaliza em: 1m 29s
# 1x Bandido de Kruin / Kruin Outlaw - Em Chinês
# R$ 12,00
# Finaliza em: 1m 29s
# 1x Shinobi da Lâmina de Névoa / Mistblade Shinobi - Chinês
# R$ 2,00
# Finaliza em: 1m 29s
# -33.26%
# 1x Átrio de Névoa / Halls of Mist - HP
# R$ 6,00
# Finaliza em: 1m 29s
# 1x Infortúnio / Misfortune - HP
# R$ 6,00
# Finaliza em: 1m 29s
# 1x Dragão da Catacumba / Catacomb Dragon - HP
# R$ 15,00
# Finaliza em: 1m 29s
# 1x Urza, Grão-lorde Artífice
# R$ 130,00
# Finaliza em: 1m 29s
# -58.33%
# *** 1x Planície / Plains - FOIL ***
# R$ 2,50
# Finaliza em: 1m 29s
# CLB 1 X Charcoal Diamond (RULEBOOK) (1/4)
# R$ 2,00
# Finaliza em: 1m 29s
# CLB 1 X Charcoal Diamond (RULEBOOK) (2/4)
# R$ 2,00
# Finaliza em: 1m 29s
# CLB 1 X Charcoal Diamond (RULEBOOK) (3/4)
# R$ 2,00
# Finaliza em: 1m 29s
# CLB 1 X Charcoal Diamond (RULEBOOK) (4/4)
# R$ 2,00
# Finaliza em: 1m 29s
# CLB 1 X Charcoal Diamond (3/4)
# R$ 1,00
# Finaliza em: 1m 29s
# 1- Baral, Chefe da Conformidade - Secret Lair Drop Series
# R$ 90,00
# Finaliza em: 1m 29s
# 1- Baral, Chefe da Conformidade - Secret Lair Drop Series
# R$ 90,00
# Finaliza em: 1m 29s
# 1 x Vitimar - NM
# R$ 1,90
# Finaliza em: 1m 29s
# 1 x Esfolador Macabro - NM
# R$ 0,90
# Finaliza em: 1m 29s
# -42.84%
# [SLD92] 1x E. Honda, Sumo Champion
# R$ 20,00
# Finaliza em: 1m 29s
# -42.84%
# [SLD92] 1x E. Honda, Sumo Champion
# R$ 20,00
# Finaliza em: 1m 29s
# -42.84%
# [SLD92] 1x E. Honda, Sumo Champion
# R$ 20,00
# Finaliza em: 1m 29s
# -42.84%
# [SLD92] 1x E. Honda, Sumo Champion
# R$ 20,00
# Finaliza em: 1m 29s
# -5.56%
# 1x Old One Eye
# R$ 9,00
# Finaliza em: 2m 3s
# -6.89%
# 1x Sloppity Bilepiper - Surge-Foil
# R$ 15,00
# Finaliza em: 3m 1s
# -6.89%
# 1x Sloppity Bilepiper - Surge-Foil
# R$ 15,00
# Finaliza em: 3m 11s
# -6.89%
# 1x Sloppity Bilepiper - Surge-Foil
# R$ 15,00
# Finaliza em: 3m 15s
# -6.89%
# 1x Sloppity Bilepiper - Surge-Foil
# R$ 15,00
# Finaliza em: 3m 19s
# -9.95%
# 1x Two-Headed Sliver - FOIL - SECRET LAIR
# R$ 18,00
# Finaliza em: 4m 28s
# -24.41%
# 1x Isu the Abominable
# R$ 20,00
# Finaliza em: 5m 3s
# -13.35%
# 1x Auntie Blyte, Bad Influence
# R$ 22,00
# Finaliza em: 6m
# -13.98%
# 1x Svyelun of Sea and Sky
# R$ 12,00
# Finaliza em: 6m 48s
# Templo do Triunfo promo pack Foil
# R$ 5,00
# R$ 15,00
# Finaliza em: 7m 28s
# -5.29%
# Monolito Sinistro - [D] [01/02]
# R$ 775,00
# R$ 800,00
# Finaliza em: 7m 28s
# 4x Angel's Grace - SP/NM - (LEIA AS INFORMAÇÕES)
# R$ 72,99
# Finaliza em: 7m 28s
# 1x Sudden Demise - NM - (LEIA AS INFORMAÇÕES)
# R$ 0,99
# Finaliza em: 7m 28s
# 1x Karoo - SP - (LEIA AS INFORMAÇÕES)
# R$ 0,99
# Finaliza em: 7m 28s
# 1x Vidas Paralelas FOIL
# R$ 180,00
# Finaliza em: 7m 28s
# 1 Molten Rain NM FOIL
# R$ 6,99
# Finaliza em: 7m 28s
# 1 X Gravecrawler (1/4)
# R$ 19,90
# Finaliza em: 7m 28s
# Leilões 1-48 de 42.720
# Páginas:  1 2 3 > >>
# Opção não existe
# Saindo do programa. Até mais!
# Opção não existe
# Saindo do programa. Até mais!
