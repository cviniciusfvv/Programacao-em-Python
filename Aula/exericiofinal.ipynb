# %% [markdown]
# ## Exercicio Final - Game e antiguidade

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

while True:
    cd = int(input("Qual opção você quer: 1 - Yu Gi Oh, 2 - Magic, 3 - Pokemon TCG, 0 - sair: ")) #escolha seu card game
    if cd == 0:
        print("Saindo do programa. Até mais!")
        break  # Encerra o loop
    if cd == 1: #Yu Gi Oh
        while True:
            yugioh = int(input("O que você procura sobre Yu Gi Oh: 1 - Cartas, 2 - Booster, 3 - Cartas avulsas, 4 - decks 0 - sair:  "))
            if yugioh == 0:
                print("Saindo do programa. Até mais!")
                break  # Encerra o loop interno
            if yugioh == 1: # cartas
                driver = webdriver.Chrome()
                driver.get('https://www.ligayugioh.com.br/?view=cards/edicoes')
                result = driver.find_element(By.XPATH, '//*[@id="tab-edc"]/tbody \n').text
                print(result)
            if yugioh == 2: # Booster
                driver = webdriver.Chrome()
                driver.get('https://www.ligayugioh.com.br/?view=cards/edicoes')
                result = driver.find_element(By.XPATH, '//*[@id="tab-edc"]/tbody \n').text
                print(result)
            if yugioh == 3: # cartas avulsas
                driver = webdriver.Chrome()
                driver.get('https://www.ligayugioh.com.br/?view=cards/edicoes')
                result = driver.find_element(By.XPATH, '//*[@id="tab-edc"]/tbody \n').text
                print(result)
            if yugioh == 4: # decks
                driver = webdriver.Chrome()
                driver.get('https://www.ligayugioh.com.br/?view=dks/decks')
                result = driver.find_element(By.XPATH, '//*[@id="card-estoque"]/div[3] \n').text
                print(result)
            else:
                print("Opção não existe")
    if cd == 2: #Magic
        while True:
            magic = int(input("O que você procura sobre Magic: 1 - Cartas, 2 - Booster, 3 - Cartas avulsas, 4 - decks 0 - sair:  "))
            if magic == 0:
                print("Saindo do programa. Até mais!")
                break  # Encerra o loop interno
            if magic == 1: # packs
                driver = webdriver.Chrome()
                driver.get('https://www.ligamagic.com.br/?view=cards%2Fsearch&card=booster+pack&tipo=1')
                result = driver.find_element(By.XPATH, '//*[@id="mtg-cards"] \n').text
                print(result)
            if magic == 2: # Booster
                driver = webdriver.Chrome()
                driver.get('https://www.ligamagic.com.br/?view=cards%2Fsearch&card=booster+box&tipo=1')
                result = driver.find_element(By.XPATH, '//*[@id="mtg-cards"]/div[1] \n').text
                print(result)
            if magic == 3: # cartas avulsas
                driver = webdriver.Chrome()
                driver.get('https://www.ligamagic.com.br/?view=leilao/listar')
                result = driver.find_element(By.XPATH, '/html/body/main/div[4]/div \n').text
                print(result)
            if magic == 4: # decks
                driver = webdriver.Chrome()
                driver.get('https://www.ligamagic.com.br/?view=dks/decks')
                result = driver.find_element(By.XPATH, '//*[@id="dks-carrossels"] \n').text
                print(result)
            else:
                print("Opção não existe")
    if cd == 3: #Pokemon tcg
        while True:
            magic = int(input("O que você procura sobre Pokemon TCG: 1 - Cartas, 2 - Booster, 3 - Cartas avulsas, 4 - decks 0 - sair:  "))
            if magic == 0:
                print("Saindo do programa. Até mais!")
                break  # Encerra o loop interno
            if magic == 1: # packs
                driver = webdriver.Chrome()
                driver.get('https://www.ligapokemon.com.br/?view=cards/search&card=categ%3D21+searchprod%3D1')
                result = driver.find_element(By.XPATH, '//*[@id="mtg-cards"] \n').text
                print(result)
            if magic == 2: # Booster
                driver = webdriver.Chrome()
                driver.get('https://www.ligapokemon.com.br/?view=cards/search&card=categ%3D10+searchprod%3D1')
                result = driver.find_element(By.XPATH, '//*[@id="mtg-cards"] \n').text
                print(result)
            if magic == 3: # cartas avulsas
                driver = webdriver.Chrome()
                driver.get('https://www.ligapokemon.com.br/?view=cards/variacao&show=alta')
                result = driver.find_element(By.XPATH, '//*[@id="card-estoque"]/div[3] \n').text
                print(result)
            if magic == 4: # decks
                driver = webdriver.Chrome()
                driver.get('https://www.ligapokemon.com.br/?view=cards/search&card=categ%3D24+searchprod%3D1')
                result = driver.find_element(By.XPATH, '//*[@id="mtg-cards"] \n').text
                print(result)
            else:
                print("Opção não existe")
    else:
        print("Opção não existe")
# Out:
# Caixa de Booster - 30th Anniversary Edition
# R$ 5.390,90 R$ 6.616,24 R$ 7.000,00
#
#
#
#
# Caixa de Booster - A Guerra da Centelha
# R$ 1.099,00 R$ 1.316,27 R$ 1.999,00
#
#
#
#
# Caixa de Booster - A Guerra dos Irmãos - Booster de Coleção
# R$ 593,99 R$ 876,35 R$ 1.027,97
#
#
#
#
# Caixa de Booster - A Guerra dos Irmãos - Booster de Colecionador
# R$ 1.141,20 R$ 1.537,55 R$ 2.049,90
#
#
#
#
# Caixa de Booster - A Guerra dos Irmãos - Booster de Draft
# R$ 599,75 R$ 795,39 R$ 949,90
#
#
#
#
# Caixa de Booster - A Guerra dos Irmãos - Booster de Jumpstart
# R$ 498,95 R$ 601,94 R$ 629,90
#
#
#
#
# Caixa de Booster - Alvorecer
# R$ 2.500,00 R$ 2.500,00 R$ 2.500,00
#
#
#
#
# Caixa de Booster - As Cavernas Perdidas de Ixalan - Booster de Coleção
# R$ 899,75 R$ 1.028,70 R$ 1.250,00
#
#
#
#
# Caixa de Booster - As Cavernas Perdidas de Ixalan - Booster de Colecionador
# R$ 1.299,99 R$ 1.678,02 R$ 2.000,00
#
#
#
#
# Caixa de Booster - As Cavernas Perdidas de Ixalan - Booster de Draft
# R$ 859,95 R$ 1.080,23 R$ 999,90
#
#
#
#
# Caixa de Booster - Batalha por Zendikar
# R$ 624,99 R$ 706,01 R$ 1.436,40
#
#
#
#
# Caixa de Booster - Battlebond
# R$ 2.499,90 R$ 2.499,90 R$ 2.499,90
#
#
#
#
# Caixa de Booster - Commander Legends - Booster de Colecionador
# R$ 3.950,00 R$ 3.982,67 R$ 3.999,00
#
#
#
#
# Caixa de Booster - Commander Legends - Booster de Draft
# R$ 1.199,90 R$ 1.199,90 R$ 1.199,90
#
#
#
#
# Caixa de Booster - Commander Legends: Batalha pelo Portal de Baldur - Booster de Coleção
# R$ 499,75 R$ 782,60 R$ 1.043,01
#
#
#
#
# Caixa de Booster - Commander Legends: Batalha pelo Portal de Baldur - Booster de Colecionador
# R$ 799,99 R$ 1.257,79 R$ 2.299,90
#
#
#
#
# Caixa de Booster - Commander Legends: Batalha pelo Portal de Baldur - Booster de Draft
# R$ 499,75 R$ 792,80 R$ 999,90
#
#
#
#
# Caixa de Booster - Commander Masters - Booster de Coleção
# R$ 1.699,75 R$ 2.547,90 R$ 3.599,00
#
#
#
#
# Caixa de Booster - Commander Masters - Booster de Colecionador
# R$ 899,75 R$ 1.475,94 R$ 2.400,00
#
#
#
#
# Caixa de Booster - Commander Masters - Booster de Draft
# R$ 1.496,99 R$ 2.437,17 R$ 3.199,90
#
#
#
#
# Caixa de Booster - Core Set 2019
# R$ 999,90 R$ 999,90 R$ 999,90
#
#
#
#
# Caixa de Booster - Core Set 2020
# R$ 543,99 R$ 546,11 R$ 598,90
#
#
#
#
# Caixa de Booster - Core Set 2021 - Booster de Colecionador
# R$ 1.799,99 R$ 1.999,59 R$ 1.999,00
#
#
#
#
# Caixa de Booster - Core Set 2021 - Booster de Draft
# R$ 758,96 R$ 844,36 R$ 799,99
#
#
#
#
# Caixa de Booster - Despertar do Mundo
# R$ 7.499,99 R$ 7.499,99 R$ 7.499,99
#
#
#
#
# Caixa de Booster - Destino Reescrito
# R$ 441,99 R$ 739,90 R$ 899,99
#
#
#
#
# Caixa de Booster - Doctor Who - Booster de Colecionador
# R$ 1.799,75 R$ 2.409,07 R$ 2.998,00
#
#
#
#
# Caixa de Booster - Dominaria
# R$ 1.499,95 R$ 1.499,95 R$ 1.499,95
#
#
#
#
# Caixa de Booster - Dominária Remasterizada - Booster de Colecionador
# R$ 1.656,79 R$ 2.197,71 R$ 2.399,90
#
#
#
#
# Caixa de Booster - Dominária Remasterizada - Booster de Draft
# R$ 999,43 R$ 1.324,20 R$ 1.620,00
#
#
#
#
# Caixa de Booster - Dominária Unida - Booster de Coleção
# R$ 720,00 R$ 900,01 R$ 1.069,90
#
#
#
#
# Caixa de Booster - Dominária Unida - Booster de Colecionador
# R$ 1.529,00 R$ 1.774,56 R$ 1.859,90
#
#
#
#
# Caixa de Booster - Dominária Unida - Booster de Draft
# R$ 719,75 R$ 919,52 R$ 999,00
#
#
#
#
# Caixa de Booster - Dominária Unida - Booster de Jumpstart
# R$ 348,96 R$ 496,88 R$ 969,99
#
#
#
#
# Caixa de Booster - Double Masters
# R$ 2.999,00 R$ 3.032,63 R$ 3.099,90
#
#
#
#
# Caixa de Booster - Double Masters 2022 - Booster de Colecionador
# R$ 1.429,40 R$ 1.734,17 R$ 2.200,00
#
#
#
#
# Caixa de Booster - Double Masters 2022 - Booster de Draft
# R$ 1.199,75 R$ 1.892,13 R$ 2.299,90
#
#
#
#
# Caixa de Booster - Dragões de Tarkir
# R$ 449,99 R$ 511,92 R$ 720,00
#
#
#
#
# Caixa de Booster - Dungeons and Dragons: Adventures in the Forgotten Realms - Booster de Coleção
# R$ 698,99 R$ 961,78 R$ 1.099,90
#
#
#
#
# Caixa de Booster - Dungeons and Dragons: Adventures in the Forgotten Realms - Booster de Colecionador
# R$ 1.099,00 R$ 1.426,14 R$ 1.899,90
# Opção não existe
# Saindo do programa. Até mais!
# Opção não existe
# Saindo do programa. Até mais!
