# %% [markdown]
# Raspagem do oscar

# %%
# !pip install beautifulsoup4
# !pip install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4) (2.5)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\carlo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: requests in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\carlo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2023.5.7)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\carlo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.magazineluiza.com.br/busca/computadores/"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find(class_="sc-dcJsrY hmLryf") #Elemento (Geral)
job_elements = results.find_all("li", class_="eJDyHN") #Elemento (Específico)

for job_element in job_elements:
    title_element = job_element.find("h2", class_="uaEbk") #Texto Descrisão
    company_element = job_element.find("p", class_="sc-kpDqfm eCPtRw sc-hoLEA kXWuGr") #Texto Valor
    print(title_element.text.strip())
    print(company_element.text.strip())
    print()
# Out:
# Computador Completo Intel Core I5 8gb de Ram Ssd 240-256gb Monitor Led 19" Hdmi
# R$ 1.070,99
#
# Computador Completo Intel Core i5 8GB SSD 512GB Windows 10 Monitor LED 19.5" HDMI 3green
# R$ 1.062,50
#
# Computador Completo Intel Core I5 8gb de Ram Ssd 240gb Monitor Led 19" Hdmi + Windows 10 e Pacote Office
# R$ 972,20
#
# Computador Completo Intel Core I5 8gb Hd 500gb com Kit Monitor 20" + Pacote Office Flex Computer
# R$ 948,51
#
# Computador Completo Intel Core i5 8GB SSD 256GB Windows 10 Monitor LED 19.5" HDMI 3green
# R$ 1.190,00
#
# Computador Gamer Completo RGB Intel Core i5 8GB HD 500GB Kit Gamer com Headset Monitor 20" Windows 10 3green Premium
# R$ 1.487,50
#
# Computador Completo 3green Desktop Intel Core i7 16GB Monitor 24" Full HD HDMI SSD 480GB Windows 10 3D-165
# R$ 1.521,50
#
# PC Computador CPU Intel Core I5, 8GB Memória ram, SSD 240GB
# R$ 718,80
#
# Pc Computador Cpu Intel Core I5 + Ssd 240gb, 8gb Memória Ram
# R$ 669,59
#
# Pc Computador Cpu Intel Core I5 + Ssd 480gb + 16gb Ram
# R$ 1.104,14
#
# Computador Completo Intel Core i5 8GB SSD 240GB Microsoft Windows 10 e Office 365 Monitor 19.5" EasyPC All
# R$ 977,50
#
# Computador Completo PC Intel Core i5 8GB SSD 240GB, Monitor 19 Led Windows 10 Pro Brx
# R$ 900,15
#
# Novo Computador Intel Core i5 8GB HD 1TB Windows 10 Teclado Mouse Desktop Pc
# R$ 692,99
#
# Computador Completo 3green Desktop Intel Core i5 16GB Monitor HDMI SSD 256GB Windows 10 3D-055
# R$ 1.350,00
#
# PC Computador CPU Mancer, Intel Core I5, 16GB De Memória ram, SSD 480GB
# R$ 846,21
#
# Computador Cpu Pc Torre Intel i5 16Gb Ssd 480Gb wifi
# R$ 929,00
#
# Computador Gamer completo Intel Core i7 16GB de Memória SSD 240GB Placa de Video Geforce 4GB Monitor 21.5
# R$ 1.764,02
#
# Computador Gamer completo Intel Core i7 16GB de Memória SSD 240GB Placa de Video Geforce 4GB Monitor 21.5
# R$ 1.840,65
#
# Computador Completo Slim Intel Core i7 16GB SSD 1TB Wifi Windows 10 Pro Monitor 24" 3green Office 3GO-060
# R$ 1.946,50
#
# Pc Gamer Computador Cpu Intel I5 Hd 1tb Memoria Ram 16gb
# R$ 1.165,50
#
# Computador Completo 3green Desktop Intel Core i7 16GB Monitor 19.5" HDMI SSD 480GB Windows 10 3D-099
# R$ 1.590,00
#
# Computador Completo Intel Core i5 16GB SSD 480GB Monitor LED 19.5" HDMI EasyPC Go
# R$ 1.459,99
#
# Computador Completo Intel Core i3 4Gb Hd 500Gb com Monitor 17'' + Pacote Office Flex Computer
# R$ 998,73
#
# Pc Computador Cpu Intel Core I5 + Ssd 240gb, 8gb Memória Ram
# R$ 743,99
#
# Pc Computador Cpu Intel Core I5 + Ssd 240gb, 8gb Memória Ram
# R$ 791,72
#
# Cpu Computador Completo Pronta para Uso DUal Core 3.0ghz 4gb DDR3 HD 160 Wi-fi - kit multimídia
# R$ 476,91
#
# Computador RGB Intel Core i7 16GB SSD 512GB Kit Gamer Monitor LED 24" Windows 10 3green Colors
# R$ 1.990,00
#
# Computador Gamer Completo I5 3.2 GHZ HD 500 GB 8GB RAM Monitor 19 Polegadas
# R$ 1.614,99
#
# Cpu Computador Completo Pronta para Uso DUal Core 3.0ghz 4gb HD 500 Wi-fi - Kit multimídia
# R$ 476,99
#
# Computador Completo Mancer, Intel Core i5, 16GB De Ram, HD 500GB, Monitor + Kit Teclado e Mouse
# R$ 1.109,90
#
# Computador Completo Intel Core i5 8GB SSD 240GB Windows 10 Wifi Monitor 19.5" LED HDMI EasyPC Desktop
# R$ 1.104,99
#
# Computador Completo 3green Desktop Intel Core i5 16GB Monitor 19.5" HDMI SSD 480GB Windows 10 3D-089
# R$ 1.181,50
#
# Pc Gamer Computador Cpu Intel core I5 Ssd 240gb Memoria Ram 16gb
# R$ 1.057,50
#
# Computador Pc Completo I5 Intel 16gb Armazenamento 480GB Wifi Nf
# R$ 1.984,03
#
# Computador Completo Cpu Intel Core I7 16gb, Ssd 480gb, Monitor 17.1", Homeoffice
# R$ 1.333,91
#
# Computador Completo Intel Core i7 16GB SSD 480GB Monitor Full HD 21.5" HDMI CorPC Fast
# R$ 1.572,49
#
# Pc Computador Cpu Core I5 650 + Ssd 240gb, 8gb Memória Ram
# R$ 771,89
#
# Computador Completo Intel Core I5 8gb de Ram Ssd 256gb Monitor Led 19" Hdmi + Windows 10 e Pacote Office
# R$ 972,20
#
# Pc Cpu Gamer Computador Intel I7 4790 4.0 Ghz + 16 Gb+ Ssd 960 gb + Fonte 500w + Wi-Fi + Bluetooth
# R$ 1.580,99
#
# Computador Gamer Completo RGB Intel Core i5 8GB SSD 480GB Kit Gamer com Headset Monitor 20" Windows 10 3green Premium
# R$ 1.436,50
#
# Computador Completo 24" Intel Core i7 16GB SSD 1TB 3green Plus
# R$ 1.793,49
#
# Computador Completo Core I5 8Gb SSD 120GB PC Intel Monitor 19" Windows 10 Wi-fi
# R$ 1.065,28
#
# Pc computador cpu intel core i5 8gb ram hd 500gb windows 10
# R$ 725,39
#
# Pc Gamer Computador Cpu Intel I5 Ssd 120gb Memoria Ram 8gb
# R$ 1.004,40
#
# Computador Completo, Intel Core I5, 8gb, Ssd 256gb, Monitor Led 15" Hdmi Bestpc Slim
# R$ 926,01
#
# Cpu Pc Gamer Computador Intel I5 2400 Mem 8gb Hd 500gb
# R$ 963,00
#
# Computador Completo Intel Core I5 8gb de Ram Ssd 256gb Monitor Led 19" Hdmi com Pacote Office
# R$ 972,20
#
# Computador Gamer Intel Core i7 16GB de Memória HD 1TB Placa de Video Geforce 2GB
# R$ 1.169,91
#
# Computador Completo Intel Core i5 8GB SSD 240GB Windows 10 Monitor 19" HDMI 3green ElitePC Slim
# R$ 1.121,99
#
# Computador Gamer Completo RGB Intel Core i7 8GB HD 1TB Kit Gamer com Headset Monitor 20" Windows 10 3green Premium
# R$ 2.239,99
#
# Computador Completo Slim Intel Core i5 16GB SSD 512GB Wifi Windows 10 Pro Monitor 19" 3green Office 3GO-029
# R$ 1.410,99
#
# Computador Completo Intel Core i5 8GB SSD 512GB Windows 10 Monitor LED 19.5
# R$ 1.179,84
#
# Computador Desktop Intel Core I5 3.2GHZ 8gb ssd 240gb * ultra-velocidade
# R$ 600,52
#
# Computador Completo Intel Core i7 6ª Geração 16GB DDR4 SSD 1TB Monitor LED 21.5" HDMI Windows 10 3green Flex 3F-048
# R$ 2.371,50
#
# Pc Gamer Cpu Computador Intel I7 4790 4.0 Ghz + 16 Gb+ Ssd 480 gb + Fonte 500w + Wi-Fi + BLUETOOTH
# R$ 1.444,14
#
# Computador Completo 8gb Hard disk 500Gb Monitor 18'5 Led Slim - Excelente desempenho
# R$ 857,79
#
# Computador Completo 3green Desktop Intel Core i5 16GB Monitor 24" Full HD HDMI SSD 480GB Windows 10 3D-155
# R$ 1.351,50
#
# Computador Fácil Intel Core i5 8GB SSD 240GB
# R$ 620,10
#
# Pc Computador Cpu Intel Core I7 Ssd 480gb / 16gb Memória Ram
# R$ 1.163,35
#
# Pc Computador Cpu Intel Core I5 + Ssd 240gb, 8gb Memória Ram
# R$ 841,64

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.magazineluiza.com.br/busca/geladeira/"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find(class_="hYHpAk")
resultado_pesq = results.find_all("li", class_="eJDyHN")

for rp in resultado_pesq:
    titulo = rp.find("h2", class_="uaEbk")
    valor = rp.find("p", class_="kXWuGr")
    print(titulo.text.strip())
    print(valor.text.strip())
    print()
# Out:
# Geladeira Brastemp Frost Free Duplex 375L Branca
# R$ 2.975,07
#
# Geladeira/Refrigerador Electrolux Manual
# R$ 2.255,06
#
# Geladeira Brastemp Frost Free Duplex 375L Inox
# R$ 3.229,05
#
# Geladeira/Refrigerador Electrolux Frost Free
# R$ 2.812,03
#
# Geladeira/Refrigerador Electrolux Frost Free Inox
# R$ 3.071,05
#
# Geladeira/Refrigerador Panasonic Frost Free Duplex
# R$ 2.944,05
#
# Geladeira/Refrigerador Brastemp Frost Free Duplex
# R$ 3.665,06
#
# Geladeira Brastemp Frost Free Duplex 400 litros cor Inox com Freeze Control - BRM54JK
# R$ 3.324,05
#
# Geladeira/Refrigerador Electrolux Frost Free
# R$ 3.679,08
#
# Geladeira/Refrigerador Electrolux 240L Branco RE31
# R$ 1.973,06
#
# Geladeira/Refrigerador Consul Frost Free Duplex
# R$ 3.007,06
#
# Geladeira/Refrigerador Electrolux Frost Free
# R$ 3.799,05
#
# Geladeira Consul Frost Free Duplex 340 litros Branca com Prateleiras Altura Flex - CRM39AB
# R$ 2.799,00
#
# Geladeira/Refrigerador Brastemp Frost Free Duplex
# R$ 3.989,05
#
# Geladeira/Refrigerador Panasonic Frost Free Duplex
# R$ 2.819,06
#
# Geladeira/Refrigerador Electrolux Frost Free
# R$ 3.383,06
#
# Geladeira/Refrigerador Esmaltec Degelo Manual
# R$ 1.644,06
#
# Geladeira Brastemp Frost Free Duplex 375 litros cor Branca com Espaço Adapt - BRM45JB
# R$ 3.099,00
#
# Geladeira Electrolux 260 Litros Cycle Defrost Branca DC35A - 110V
# R$ 2.099,00
#
# Geladeira/Refrigerador LG Frost Free 395L
# R$ 3.039,05
#
# Geladeira/Refrigerador Electrolux Frost Free
# R$ 4.844,05
#
# Geladeira Electrolux Frost Free Inverter 431L Efficient Duplex Branco (IF55)
# R$ 3.399,00
#
# Geladeira/Refrigerador Electrolux Degelo Prático 240 Litros Cycle Defrost Branco RE31 - 220V
# R$ 1.626,58
#
# Geladeira/Refrigerador Brastemp Frost Free Inverse
# R$ 4.605,06
#
# Geladeira Cycle Defrost Electrolux 240 Litros Degelo Prático Branco RE31 - 110V
# R$ 1.799,00
#
# Geladeira/Refrigerador Panasonic Frost Free
# R$ 3.599,01
#
# Geladeira/Refrigerador Electrolux Multidoor
# R$ 6.269,05
#
# Geladeira/Refrigerador Electrolux Frost Free
# R$ 4.364,03
#
# Geladeira Electrolux Frost Free Inverter 409L Água na Porta AutoSense cor Inox Look (IW45S)
# R$ 3.499,00
#
# Geladeira Consul Frost Free Duplex 386 litros com Altura Flex cor Inox CRM44AK
# R$ 2.999,00
#
# Geladeira/Refrigerador Brastemp Frost Free
# R$ 6.554,05
#
# Geladeira Brastemp Frost Free Side Inverse 3 Portas A+++ 554 litros cor Inox - BRO85AK
# R$ 6.399,00
#
# Geladeira Consul Frost Free Duplex com Espaço Flex e Painel Eletrônico Externo 451 litros cor Branca - CRM56FB
# R$ 3.324,05
#
# Geladeira/Refrigerador Electrolux Frost Free
# R$ 3.719,07
#
# Geladeira/Refrigerador Panasonic Frost Free
# R$ 5.009,26
#
# Geladeira Electrolux Frost Free Inverter 431L Efficient Duplex Cor Inox (IF55S)
# R$ 3.699,00
#
# Geladeira/Refrigerador Esmaltec Cycle Defrost
# R$ 2.161,06
#
# Geladeira/Refrigerador Electrolux Frost Free
# R$ 3.324,05
#
# Geladeira/Refrigerador Consul Frost Free Duplex
# R$ 3.665,06
#
# Geladeira Duplex Brastemp 375 Litros Frost Free Branca BRM44HB - 110V
# R$ 2.869,00
#
# Geladeira Consul Frost Free Duplex 397 litros Evox com freezer embaixo - CRE44BK
# R$ 3.704,05
#
# Geladeira Brastemp Frost Free Duplex 375 litros cor Inox com Espaço Adapt - BRM45JK
# R$ 3.349,00
#
# Geladeira/Refrigerador Consul Cycle Defrost Duplex
# R$ 2.537,06
#
# Geladeira/Refrigerador Panasonic Frost Free
# R$ 4.323,06
#
# Geladeira/Refrigerador Consul Frost Free Duplex
# R$ 3.869,10
#
# Geladeira Consul Frost Free Duplex com Espaço Flex e Painel Eletrônico Externo 451 litros cor Inox - CRM56FK
# R$ 3.599,00
#
# Geladeira/Refrigerador Midea Frost Free
# R$ 5.733,06
#
# Geladeira/Refrigerador Continental Frost Free
# R$ 2.799,01
#
# Geladeira/Refrigerador Electrolux 240L Branco RE31
# R$ 1.973,06
#
# Geladeira Consul Frost Free 342 litros cor Inox com Gavetão Hortifruti - CRB39AK
# R$ 2.469,00
#
# Geladeira/Refrigerador Samsung Frost Free Duplex
# R$ 3.759,07
#
# Geladeira/Refrigerador Electrolux Frost Free
# R$ 3.299,00
#
# Geladeira/Refrigerador Duplex Electrolux 260 Litros Cycle Defrost Branco DC35A - 220V
# R$ 2.041,99
#
# Geladeira Duplex Electrolux 310 Litros Frost Free Branco TF39 220V
# R$ 2.489,00
#
# Geladeira/Refrigerador Continental Frost Free Duplex Branca 394 Litros (TC44)
# R$ 2.699,00
#
# Geladeira Consul Frost Free Duplex 340 L Branca
# R$ 2.887,00
#
# Geladeira Consul Frost Free Duplex 386 litros com Altura Flex cor branca CRM44AB
# R$ 2.849,00
#
# Geladeira/Refrigerador Continental Frost Free Duplex Prata 370 Litros (TC41S)
# R$ 2.699,00

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.americanas.com.br/busca/console"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find(class_="gGJHBq")
resultado_pesq = results.find_all("li", class_="kyEfos")

for rp in resultado_pesq:
    titulo = rp.find("h2", class_="kYncIC")
    valor = rp.find("p", class_=" juBAtS")
    print(titulo.text.strip())
    print(valor.text.strip())
    print()
