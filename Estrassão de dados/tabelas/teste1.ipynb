# %%
pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from lxml import html
from bs4 import BeautifulSoup

# %%
import pandas as pd

url = 'https://pt.wikipedia.org/wiki/Campeonato_Brasileiro_de_Futebol_-_S%C3%A9rie_B'

# Ler todas as tabelas da página
tabelas = pd.read_html(url)

# Imprimir todas as tabelas
for i, tabela in enumerate(tabelas):
    print(f"Tabela {i + 1}:\n{tabela}\n{'='*30}\n")
# Out:
# Tabela 1:
#     0                                                  1
# 0 NaN  Esta página cita fontes, mas que não cobrem to...
# ...
#
# Tabela 2:
#                              Brasileirão Série Betano  \
#                                               Série B
# 0          Campeonato Brasileiro de Futebol - Série B
# 1                                        Dados gerais
# 2                                         Organização
# 3                                             Edições
# 4                                        Outros nomes
# 5                                    Local de disputa
# 6                                   Número de equipes
# 7                                             Sistema
# 8   Dados históricos  Primeiro vencedor Villa Nova...
# 9                                    Dados históricos
# 10                                  Primeiro vencedor
# 11                                    Último vencedor
# 12                                     Maior vencedor
# ...

# %%
listabb = url[12]
listabb
# Out:
# 'i'

# %%
for i in range (1, 18):
    print(pd.read_html(url))
# Out:
# [    0                                                  1
# 0 NaN  Esta página cita fontes, mas que não cobrem to...,                              Brasileirão Série Betano  \
#                                               Série B
# 0          Campeonato Brasileiro de Futebol - Série B
# 1                                        Dados gerais
# 2                                         Organização
# 3                                             Edições
# 4                                        Outros nomes
# 5                                    Local de disputa
# 6                                   Número de equipes
# 7                                             Sistema
# 8   Dados históricos  Primeiro vencedor Villa Nova...
# 9                                    Dados históricos
# 10                                  Primeiro vencedor
# 11                                    Último vencedor
# 12                                     Maior vencedor
# ...

# %%
add_data = []
for i in range (1,15):
    add_data.append(pd.read_html(url)[i])
add_data
# Out:
# [                             Brasileirão Série Betano  \
#                                                Série B
#  0          Campeonato Brasileiro de Futebol - Série B
#  1                                        Dados gerais
#  2                                         Organização
#  3                                             Edições
#  4                                        Outros nomes
#  5                                    Local de disputa
#  6                                   Número de equipes
#  7                                             Sistema
#  8   Dados históricos  Primeiro vencedor Villa Nova...
#  9                                    Dados históricos
#  10                                  Primeiro vencedor
#  11                                    Último vencedor
#  12                                     Maior vencedor
#  13  Ascensão e descenso  Promove para Campeonato B...
#  14                                Ascensão e descenso
# ...

# %%
import pandas as pd

# %%
df = pd.concat(add_data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 290 entries, 0 to 14
# Data columns (total 42 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   (Brasileirão Série Betano, Série B)                     24 non-null     object
#  1   (Brasileirão Série Betano, Série B.1)                   24 non-null     object
#  2   Dados históricos                                        3 non-null      object
#  3   Dados históricos.1                                      3 non-null      object
#  4   Ascensão e descenso                                     2 non-null      object
#  5   Ascensão e descenso.1                                   2 non-null      object
#  6   Informações adicionais                                  1 non-null      object
#  7   Informações adicionais.1                                1 non-null      object
# ...
