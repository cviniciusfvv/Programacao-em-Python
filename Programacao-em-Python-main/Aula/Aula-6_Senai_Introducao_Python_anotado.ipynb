# %% [markdown]
# # Aula 6: Introdução à Linguagem de Programação Python
# Bem vindo ao Google Colaboratory! Nós iremos utilizar essa plataforma para fazer nossas atividades com o Python. Vamos fazer alguns testes?
#
# ## Tratamento de Exceção

# %% [markdown]
# Uma exceção é algo inesperado, fora do planejado que ocorre durante a execução de um programa. Por exemplo, você quer realizar alguma operação aritmética (uma divisão) envolvendo dois números, mas acaba digitando uma letra no lugar de um dos números, o python irá gerar um erro na execução dessa operação(comando), chamado de exceção.

# %% [markdown]
# ## Exemplo

# %%
x = 18

y = 20

print(x / y)    # Operação aritmética irá gerar um erro (Exceção)

ex
# Out:
# 0.9

# %% [markdown]
# **OBS**: A operação aritmética de multiplicação entre as duas varáveis acima não produz erro, pois o python considera essa operação como uma operação de repetição de caracteres.
#
# Além de abortar (parar) o programa, muitas vezes esses erros trazem informações técnicas desnecessárias ao usuário final. O tratamento de exceções impede que o programa seja abortado (paralisado) e, permite que o programador substitua as mensagens de erro da linguagem por uma mensagem mais amigável contendo apenas um código do erro. Para que isso aconteça, é necessário que o programa "capture" (catch, em inglês) tais erros e trate-os para que a execução não seja abortada.
#
# ### Tratamento de Exceção
# Em Python, assim como em muitas linguagens, o tratamento de erro é feito na sua forma mais básica com os comandos try e except.
#
# Sua forma geral é semelhante a muitas linguagens de alto de nível:
#
# ![try.png](data:image/png;base64,...)

# %%
try:
    print(x / y)

except:
   print("Erro na execução do comando. Verifique os tipos das variáveis ou zero no denominador")
# Out:
# 0.9

# %%
while True:
    try:
        x = float(input("Por favor, digite um numero: "))
        print("Ai sim marreco, você digitou:", x)
        break
    except ValueError:
        print("Porra marreco, é para digitar um numero!!!!!  tente de novo... mas digite um numero seu porra ")
# Out:
# Ai sim marreco, você digitou: 2.5

# %%
def imprima_ordenado(colecao):
    try:
        colecao.sort()
    except AttributeError:
        print ('Imutável')
        pass
    print(colecao)

imprima_ordenado([3, 5, 2])
imprima_ordenado(set((4, 3, 2)))
imprima_ordenado('132')
# Out:
# [2, 3, 5]
# Imutável
# {2, 3, 4}
# Imutável
# 132

# %% [markdown]
# ---

# %% [markdown]
# # Exercício 01
#
# Faça um script Py que realize um tratamento por excessão no exemplo abaixo

# %%
try:
  num = int(input("Digite um numero:"))
  resultado = 30 / num
  print (resultado)
except:
  print("O marreco, vai ser burro la na sua casa!!!!")
# Out:
# O marreco, vai ser burro la na sua casa!!!!

# %% [markdown]
# # Exercício 02
#
# Corrija o exercício abaixo

# %%
x = 10
y = 5

try:
    r=x/y
except:
    print("Erro na Divisão!!")
except:
    print("Deu certo!!")
finally:
    print("FIM!!")
# Out:
#   File "C:\Users\aluno\AppData\Local\Temp\ipykernel_11844\3644918848.py", line 8
#     except:
#
# ^
# SyntaxError: default 'except:' must be last

# %% [markdown]
# # Exercício 03
#
# Faça um programa que solicite ao usuário 2 números inteiros. A seguir, calcule e mostre a divisão do primeiro pelo segundo. Obrigatório a inclusão do bloco try-except nas leituras (ValueError) e no cálculo da divisão (ZeroDivisionError). O programa deve ter também a clásula "finally" com a mensagem "FIM!!". Atenção: O programa só continua se não houver erro.

# %%
try:
  x = int(input("Digite o primeiro número:"))
except ValueError as ve:
        print(ve)

try:
  y = int(input("Digite o segundo número:"))
except ValueError as valueError:
        print(valueError)

try:
   z = x/y
except ZeroDivisionError:
    z = 0

finally:
    print("FIM!!")
# Out:
# FIM!!

# %% [markdown]
# # Exercicio 4
#
# Faça um aplicativo que verifque o usuario e senha em tela de login, caso o usurio digite uma senha diferente exibir uma mensagem de exceção!!

# %%
try:
  email = str(input("Digite seu email:"))
  senha = int(input("Digite sua senha:"))
except ValueError as valueError:
        print("Você erro algo marreco")
finally:
      print("ai sim marreco")
# Out:
# ai sim marreco

# %% [markdown]
# # Exercicio 5
#
# Faça uma aplicação Py que tenha uma função que calcule o valor medio entre 4 valores. Caso o usuario digite algo diferente de numero exibir uma excessão

# %%
try:
    a1 = float(input("Digite a1: "))
    a2 = float(input("Digite a2: "))
    a3 = float(input("Digite a3: "))
    a4 = float(input("Digite a4: "))
    def calcula_media(a1, a2, a3, a4):
        media = (a1 + a2 + a3 + a4) / 4
        if media >= 6 and media < 8:
            print("Fez sua obrigação")
        elif media >= 8:
            print("Fez sua obrigação 2.0")
        else:
            print("Perdeu seu pc seu marreco")
        print(f"Nota final: {media:.2f}")
    calcula_media(a1, a2, a3, a4)
except ValueError as valueError:
    print("Algo de errado não está certo")
# Out:
# Algo de errado não está certo
