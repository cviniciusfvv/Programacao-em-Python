# %% [markdown]
# ## Exercicio
#
# Selecione um site com tabelas (apos a verificação do robots.txt) e execute os paços acima buscando dados com o pandas e gerandográficos com o plotly

# %%
import plotly.express as go
import pandas as pd

# %%
url = 'https://pt.wikipedia.org/wiki/Lista_de_concentra%C3%A7%C3%B5es_urbanas_do_Brasil_por_popula%C3%A7%C3%A3o'
html = pd.read_html(url, match= 'Grande concentração')
html
# Out:
# [     # Grande concentração urbana[1]      Unidade federativa  \
#  0    1                     São Paulo               São Paulo
#  1    2                Rio de Janeiro          Rio de Janeiro
#  2    3                Belo Horizonte            Minas Gerais
#  3    4                      Brasília  Distrito Federal Goiás
#  4    5                        Recife              Pernambuco
#  5    6                  Porto Alegre       Rio Grande do Sul
#  6    7                     Fortaleza                   Ceará
#  7    8                      Curitiba                  Paraná
#  8    9                      Salvador                   Bahia
#  9   10                       Goiânia                   Goiás
#  10  11                      Campinas               São Paulo
#  11  12                        Manaus                Amazonas
#  12  13                         Belém                    Pará
#  13  14                       Vitória          Espírito Santo
# ...

# %%
cidades = html[0]
cidades
# Out:
#      # Grande concentração urbana[1]      Unidade federativa  \
# 0    1                     São Paulo               São Paulo
# 1    2                Rio de Janeiro          Rio de Janeiro
# 2    3                Belo Horizonte            Minas Gerais
# 3    4                      Brasília  Distrito Federal Goiás
# 4    5                        Recife              Pernambuco
# 5    6                  Porto Alegre       Rio Grande do Sul
# 6    7                     Fortaleza                   Ceará
# 7    8                      Curitiba                  Paraná
# 8    9                      Salvador                   Bahia
# 9   10                       Goiânia                   Goiás
# 10  11                      Campinas               São Paulo
# 11  12                        Manaus                Amazonas
# 12  13                         Belém                    Pará
# 13  14                       Vitória          Espírito Santo
# ...

# %%
for i in range (1, 18):
    print(pd.read_html(url))
# Out:
# [     # Grande concentração urbana[1]      Unidade federativa  \
# 0    1                     São Paulo               São Paulo
# 1    2                Rio de Janeiro          Rio de Janeiro
# 2    3                Belo Horizonte            Minas Gerais
# 3    4                      Brasília  Distrito Federal Goiás
# 4    5                        Recife              Pernambuco
# 5    6                  Porto Alegre       Rio Grande do Sul
# 6    7                     Fortaleza                   Ceará
# 7    8                      Curitiba                  Paraná
# 8    9                      Salvador                   Bahia
# 9   10                       Goiânia                   Goiás
# 10  11                      Campinas               São Paulo
# 11  12                        Manaus                Amazonas
# 12  13                         Belém                    Pará
# 13  14                       Vitória          Espírito Santo
# ...

# %%
add_data = []
tables = pd.read_html(url)

num_tables = len(tables)

for i in range(min(10, num_tables)):
    add_data.append(tables[i])

add_data
# Out:
# [     # Grande concentração urbana[1]      Unidade federativa  \
#  0    1                     São Paulo               São Paulo
#  1    2                Rio de Janeiro          Rio de Janeiro
#  2    3                Belo Horizonte            Minas Gerais
#  3    4                      Brasília  Distrito Federal Goiás
#  4    5                        Recife              Pernambuco
#  5    6                  Porto Alegre       Rio Grande do Sul
#  6    7                     Fortaleza                   Ceará
#  7    8                      Curitiba                  Paraná
#  8    9                      Salvador                   Bahia
#  9   10                       Goiânia                   Goiás
#  10  11                      Campinas               São Paulo
#  11  12                        Manaus                Amazonas
#  12  13                         Belém                    Pará
#  13  14                       Vitória          Espírito Santo
# ...

# %%
df = pd.concat(add_data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 25
# Data columns (total 10 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   #                                                                          26 non-null     float64
#  1   Grande concentração urbana[1]                                              52 non-null     object
#  2   Unidade federativa                                                         52 non-null     object
#  3   População (2022)[3]                                                        26 non-null     object
#  4   Municípios participantes                                                   26 non-null     object
#  5   Posição                                                                    26 non-null     float64
# ...

# %%
import plotly.express as px

fig = px.funnel(dados, x='Grande concentração urbana[1]', y='População (2022)[3]')

fig.show()
